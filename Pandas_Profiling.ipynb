# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Pandas-Profiling-Report" data-toc-modified-id="Pandas-Profiling-Report-1">Pandas Profiling Report</a></span></li></ul></div>

# %% [markdown]
# # Pandas Profiling Report
#
# ###### Full transparency, I learned about pandas profiling after completion of my coursework and it is an extremely simple tool for getting an overall understanding of the data and what is important.  I used pandas profiling after my inital EDA of the dataset in this exercise, as I wanted to show my proficiency with Python in exploring, visualizing, and manipulating the data, as well as finding my own results and information.  I used pandas profiling after the fact to both confirm my findings, as well as see if there are any other interesting points I forgot to look at.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas_profiling as pro

# %%
df = pd.read_excel('HOSPITAL_SAFETY.xlsx', sheet_name=0)
df.head()
# Out:
#    HOSP.ID                              NAME  COUNTY  REGION URBAN_RURAL  \
# 0    10001  SOUTHEAST ALABAMA MEDICAL CENTER    1340       5      OURBAN
# 1    10005     MARSHALL MEDICAL CENTER SOUTH    1470       5       RURAL
# 2    10006    ELIZA COFFEE MEMORIAL HOSPITAL    1380       5      OURBAN
# 3    10007          MIZELL MEMORIAL HOSPITAL    1190       5       RURAL
# 4    10008       CRENSHAW COMMUNITY HOSPITAL    1200       5       RURAL
#
#    WAGE_INDEX  RESIDENT_TO_BEDS  BEDS   DSHPCT  COST_TO_CHARGE    ...      \
# 0      0.7704               0.0   408  0.29862           0.197    ...
# 1      0.8212               0.0   204  0.27654           0.303    ...
# 2      0.7325               0.0   358  0.24028           0.186    ...
# 3      0.6874               0.0    78  0.19347           0.368    ...
# 4      0.6973               0.0    29  0.36918           0.493    ...
#
#     CASEMIX                  TYPE  \
# 0  1.750650  Acute Care Hospitals
# ...

# %%
pro.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
